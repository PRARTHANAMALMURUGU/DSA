# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/count_characters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="HELLO WORLD"
print("The character count of the given string is",len(s))
# Out:
# The character count of the given string is 11

# %%
s="HELLO WORLD"
count=0
for ch in s:
  count+=1
print("The character count of the given string is",count)
# Out:
# The character count of the given string is 11
