# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/countVowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def vows(s):
  count=0
  vowels="aeiouAEIOU"
  for ch in s:
    if ch in vowels:
      count+=1
  return count
vows("grapes")
# Out:
# 2
