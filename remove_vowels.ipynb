# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/remove_vowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def rem_vowels(s):
  vowels="aeiou"
  result=[letter for letter in s if letter.lower() not in vowels]
  result=''.join(result)
  print(result)
rem_vowels("Python")
rem_vowels("Colab")
# Out:
# Pythn
# Clb
