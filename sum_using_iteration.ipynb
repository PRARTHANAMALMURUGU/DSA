# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/sum_using_iteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr=[1,2,3,4,5]
sum=0
for num in arr:
  sum+=num
print("Sum of the array is ",sum)
# Out:
# Sum of the array is  15
