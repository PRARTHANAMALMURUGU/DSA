# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/removeSpaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def space(s):
  return s.replace(" ","")
space("hello I am running")
# Out:
# 'helloIamrunning'
