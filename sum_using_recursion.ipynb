# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/sum_using_recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum(arr):
  if len(arr)==1:
    return arr[0]
  return arr[0]+sum(arr[1:])
nums=[1,2,3,4,5]
print(sum(nums))
# Out:
# 15
