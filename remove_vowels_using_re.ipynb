# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/remove_vowels_using_re.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
def rem_vowels(s):
  return (re.sub("[aeiouAEIOU]","",s))
print(rem_vowels("Hello World"))
# Out:
# Hll Wrld
