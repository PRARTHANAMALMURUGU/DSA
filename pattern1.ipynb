# %% [markdown]
# <a href="https://colab.research.google.com/github/PRARTHANAMALMURUGU/DSA/blob/main/pattern1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter n for n*n stars:"))
for i in range(1,n+1):
  print(n*'*')
# Out:
# Enter n for n*n stars:4
# ****
# ****
# ****
# ****
